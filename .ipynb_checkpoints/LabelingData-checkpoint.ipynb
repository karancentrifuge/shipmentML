# %%
import pandas as pd
import numpy as np

# %%
#Read in the data
jan2017Data = pd.read_csv('AIS_2017_01_Zone10.csv')

# %%
#Subset data for faster computation
jan2017Data = jan2017Data.iloc[:1000000]

# %%
#Change a column to datetime 
jan2017Data['BaseDateTime'] = pd.to_datetime(jan2017Data['BaseDateTime'])

# %%
jan2017Data.columns
# Out:
# Index(['MMSI', 'BaseDateTime', 'LAT', 'LON', 'SOG', 'COG', 'Heading',
#        'VesselName', 'IMO', 'CallSign', 'VesselType', 'Status', 'Length',
#        'Width', 'Draft', 'Cargo'],
#       dtype='object')

# %%
# def f(x):
#     print(x)
#     d = {name:x[name] for name in x.columns}
#     d['differential'] = x['BaseDateTime'].diff()
#     return pd.Series(d, index=list(d.keys()))

aggDf = jan2017Data.groupby('MMSI', sort=False)\
                   .apply(lambda df: df.sort_values(by='BaseDateTime'))\
#                    .groupby('MMSI', sort=False)
#                    .apply(f)

# new = aggDf.apply(f)

# %%
mux = pd.MultiIndex.from_arrays([
    list('aaaabbbbbccddddd'),
    list('tuvwtuvwtuvwtuvw')
], names=['one', 'two'])

df = pd.DataFrame({'col': np.arange(len(mux))}, mux)

# %%
df.index
# Out:
# MultiIndex([('a', 't'),
#             ('a', 'u'),
#             ('a', 'v'),
#             ('a', 'w'),
#             ('b', 't'),
#             ('b', 'u'),
#             ('b', 'v'),
#             ('b', 'w'),
#             ('b', 't'),
#             ('c', 'u'),
#             ('c', 'v'),
#             ('d', 'w'),
#             ('d', 't'),
#             ('d', 'u'),
#             ('d', 'v'),
#             ('d', 'w')],
#            names=['one', 'two'])

# %%
aggDf.groupby(level=0,axis=1).apply(lambda val: print(type(val)))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# Empty DataFrame
# Columns: []
# Index: []

# %%
aggDf
# Out:
#                        MMSI        BaseDateTime       LAT        LON   SOG  \
# MMSI
# 367114690 0       367114690 2017-01-01 00:00:06  48.51094 -122.60705   0.0
#           290     367114690 2017-01-01 00:01:17  48.51093 -122.60705   0.0
#           831     367114690 2017-01-01 00:02:26  48.51094 -122.60707   0.0
#           1799    367114690 2017-01-01 00:03:27  48.51096 -122.60707   0.0
#           3992    367114690 2017-01-01 00:04:36  48.51094 -122.60707   0.0
# ...                     ...                 ...       ...        ...   ...
# 338169735 979702  338169735 2017-01-02 03:29:47  37.80914 -122.39951  27.2
#           979705  338169735 2017-01-02 03:30:48  37.81282 -122.40810  26.8
#           979706  338169735 2017-01-02 03:31:49  37.81316 -122.41739  26.1
#           979716  338169735 2017-01-02 03:32:50  37.81191 -122.42675  26.5
#           980513  338169735 2017-01-02 03:35:54  37.80660 -122.43247   0.0
#
# ...

# %%
#ship is 316018851
jan2017Data.sort_values('BaseDateTime').loc[jan2017Data['MMSI'] == 367530080]

# %%
for k, v in jan2017Data.groupby('MMSI', sort=False):
    print(k)
    print(v)
    break
# Out:
# 367114690
#              MMSI        BaseDateTime       LAT        LON  SOG   COG  \
# 0       367114690 2017-01-01 00:00:06  48.51094 -122.60705  0.0 -49.6
# 290     367114690 2017-01-01 00:01:17  48.51093 -122.60705  0.0 -49.6
# 831     367114690 2017-01-01 00:02:26  48.51094 -122.60707  0.0 -49.6
# 1799    367114690 2017-01-01 00:03:27  48.51096 -122.60707  0.0 -49.6
# 3992    367114690 2017-01-01 00:04:36  48.51094 -122.60707  0.0 -49.6
# ...           ...                 ...       ...        ...  ...   ...
# 994877  367114690 2017-01-02 00:15:15  48.51092 -122.60707  0.0 -49.6
# 997708  367114690 2017-01-02 03:17:35  48.51093 -122.60705  0.0 -49.6
# 998475  367114690 2017-01-02 03:28:36  48.51092 -122.60705  0.0 -49.6
# 998733  367114690 2017-01-02 03:29:44  48.51092 -122.60705  0.0 -49.6
# 998879  367114690 2017-01-02 03:32:56  48.51092 -122.60707  0.0 -49.6
#
#         Heading VesselName  IMO CallSign  VesselType                  Status  \
# ...

# %%
jan2017Data.head()
